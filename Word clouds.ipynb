# %% [markdown]
# ## This notebook is for creating Word Cloud for War and Peace and Wikipedia corporas

# %%
#! pip install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import cv2

# %%
words_GT_wiki = np.load('top words/words_WIKI_GT.txt',allow_pickle=True)
counts_GT_wiki = np.load('top words/counts_WIKI_GT.txt',allow_pickle=True)

words_GT = np.load('top words/words_GT.txt',allow_pickle=True)
counts_GT = np.load('top words/counts_GT.txt',allow_pickle=True)

# %%
wiki_dict  = {}
for i, word in enumerate(words_GT_wiki):
    wiki_dict[word] = counts_GT_wiki[i]

# %%
wp_dict  = {}
for i, word in enumerate(words_GT):
    wp_dict[word] = counts_GT[i]

# %% [markdown]
# ### Wikipedia

# %%
img = np.uint8(cv2.imread('top words/cloud.png'))
wordcloud = WordCloud(stopwords = {}, mask = img, background_color=None, mode='RGBA').generate_from_frequencies(wiki_dict)

f = {'size' : 15}
plt.rc('font', **f)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Top words in Wikipedia')
plt.axis('off')
plt.savefig('top words/Word Clouds/word_cloud_wiki1.png')
plt.show()

# %%
img = np.uint8(cv2.imread('top words/wiki.png'))
wordcloud = WordCloud(stopwords = {}, mask = img, background_color=None, mode='RGBA').generate_from_frequencies(wiki_dict)

f = {'size' : 15}
plt.rc('font', **f)
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Top words in Wikipedia')
plt.axis('off')
plt.savefig('top words/Word Clouds/word_cloud_wiki2.png')
plt.show()

# %% [markdown]
# ### War and Peace

# %%
img = np.uint8(cv2.imread('top words/cloud.png'))
wordcloud = WordCloud(stopwords = {}, mask = img, background_color=None, mode='RGBA').generate_from_frequencies(wp_dict)

f = {'size' : 15}
plt.rc('font', **f)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Top words in War and Piece')
plt.axis('off')
plt.savefig('top words/Word Clouds/word_cloud_wp1.png')
plt.show()

# %%
img = np.uint8(cv2.imread('top words/peace.jpg'))
img = img[:1000]
wordcloud = WordCloud(stopwords = {}, mask = img, background_color=None, mode='RGBA').generate_from_frequencies(wp_dict)

f = {'size' : 15}
plt.rc('font', **f)
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Top words in War and Piece')
plt.axis('off')
plt.savefig('top words/Word Clouds/word_cloud_wp2.png')
plt.show()
